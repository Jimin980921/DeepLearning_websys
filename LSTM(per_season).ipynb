# %%
from math import sqrt
from numpy import array
from numpy import mean
from numpy import std
from pandas import DataFrame
from pandas import concat
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from matplotlib import pyplot

# %%
import math
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import LSTM, Dense
from tensorflow.python.keras.callbacks import EarlyStopping

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-a2dbfaa0-5d7a-420c-9dcd-acec97e3f0bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2dbfaa0-5d7a-420c-9dcd-acec97e3f0bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
# 데이터 입력 
import openpyxl
filename = "상명대_전력수요예측_지수평활 sheet1.xlsx" 
book = openpyxl.load_workbook(filename) #엑셀파일 book 변수에 저장
sheet=book.worksheets[0] #첫번쨰 워크시트 저장

# %%
 data = []
 for row in sheet.rows: #전체 행에대하여 반복 실행
   data.append([
              row[0].value, #1열 데이터
              row[1].value, #2열 데이터
              row[2].value, #3열 데이터
              row[3].value, #4열 데이터
              row[4].value, #5열 데이터
              row[5].value  #6열 데이터
              ])

# %%
import math
import pandas as pd
import numpy as np
data=pd.DataFrame(data[3:])
data.columns=["Name","No","Date","Time","P.D","Temp"]
data
# Out:
#      Name  No       Date  Time       P.D  Temp
# 0      신정   8 2018-01-01     1  6151.290  -3.2
# 1      신정   8 2018-01-01     2  6035.190  -3.3
# 2      신정   8 2018-01-01     3  6000.090  -3.7
# 3      신정   8 2018-01-01     4  5970.930  -4.0
# 4      신정   8 2018-01-01     5  6025.200  -4.2
# ...   ...  ..        ...   ...       ...   ...
# 8755    0   1 2018-12-31    20  7457.955  -3.7
# 8756    0   1 2018-12-31    21  7005.975  -4.6
# 8757    0   1 2018-12-31    22  6709.110  -5.4
# 8758    0   1 2018-12-31    23  6332.730  -5.2
# 8759    0   1 2018-12-31    24  6096.750  -5.5
#
# [8760 rows x 6 columns]

# %%
#계절
from datetime import date

date_=[]
a=len(data)
for i in range(0,a):
    month=data['Date'][i].month
    if(i<a and 3<=month<=5):
        date__='spring'
        date_.append(date__)
    elif(i<a and 6<=month<=8):
        date__='summer'
        date_.append(date__)
    elif(i<a and 9<=month<=11):
        date__='fall'
        date_.append(date__)
    elif(i<a and (month==12 or 2 or 1)):
        date__='winter'
        date_.append(date__)
data['season']=date_

# %% [markdown]
# # **계절 모델**

# %%
#계절별 데이터 가져오기  
def find_season(W_season):
  is_season_data = data['season'] == W_season
  season_data = data[is_season_data]
  heat_data=season_data["P.D"]
  heat_data=pd.DataFrame(heat_data)
  heat_data = np.array(heat_data)
  return heat_data

# %%
heat_data=find_season('winter')
number_of_whole_day = int(heat_data.shape[0]/24)
print(f"Number of Whole day: {number_of_whole_day}")

# #하루를 예측하는 것이므로 하루를 제외한 나머지는 train+vald으로 지정
# number_of_trainval_day=number_of_whole_day-1
# print(f"Number of train and validation day: {number_of_trainval_day}")

#train+val에서 80%를 훈련셋으로 지정  
number_of_train_day = int(number_of_whole_day * 0.8) 
print(f"Number of train day: {number_of_train_day}")
# Out:
# Number of Whole day: 90
# Number of train day: 72

# %%
#train_data중에서 
train_data=heat_data[:number_of_train_day*24]
print(f"Number of train data: {train_data.shape}")

# valid_data=heat_data[number_of_train_day*24:-24]
# print(f"Number of validation data: {valid_data.shape}")

test_data = heat_data[-24:]
print(f"Number of test data: {test_data.shape}")
# Out:
# Number of train data: (1728, 1)
# Number of test data: (24, 1)

# %%
#데이터 전처리 
#이유1.LSTM내부적으로 선형 결합의 결과값을 활성화 함수를 거치는데, 
#이때 입력값을 0과 1사이로 만든다. 입력값을 0과 1사이로 만들지 않는다면 
#그레디언트 소실이 발생할 가능성이 커짐.

#이유2.입력 특성이 두가지 이상인 경우, 두 특성의 범위가 많이 다르면 모델성능 떨어짐.

minmax_scaler = MinMaxScaler(feature_range=(0, 1))

# %%
#데이터 스케일링(0,1 사이값으로 변환)
min_max_normalized_train_data=minmax_scaler.fit_transform(train_data)

#fit은 사용하면 안됨.train data에서 fit했던 기준들을 이용해야하기 때문
# min_max_normalized_valid_data = minmax_scaler.transform(valid_data)
min_max_normalized_test_data = minmax_scaler.transform(test_data)

#스케일링된 결과
print(min(train_data), max(train_data))
print(min(min_max_normalized_train_data), max(min_max_normalized_train_data))
# Out:
# [1500.] [12434.595]
# [0.] [1.]

# %%
#numpy를 pandas로 변환
min_max_normalized_train_data = pd.DataFrame(min_max_normalized_train_data)[0]
# min_max_normalized_valid_data = pd.DataFrame(min_max_normalized_valid_data)[0]
min_max_normalized_test_data = pd.DataFrame(min_max_normalized_test_data)[0]

# %%
#학습데이터, 결과데이터 배열로 return  
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    start = sequence.index.start
    for i in range(start, len(sequence)+start):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > start + len(sequence)-1:
            break
        # gather input and output parts of the pattern
        if start > 90:
            a = i - start
            b = end_ix - start
        else:
            a = i
            b = end_ix
        # seq_x, seq_y = sequence[a:b], sequence[end_ix]
        seq_x, seq_y = sequence[a:b], sequence[b]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
#데이터 split을 위한 값. 2개의 input, 1개의 result   
## Ex) [1, 2, 3, 4, 5], n_steps = 2 -> [[1, 2, [3]], [2, 3, [4]], [3, 4, [5]]]

n_step = 2

x_train, y_train = split_sequence(min_max_normalized_train_data, n_step)
# x_valid, y_valid = split_sequence(min_max_normalized_valid_data, n_step)
x_test, y_test = split_sequence(min_max_normalized_test_data, n_step)

print(x_train.shape)
print(y_train.shape)
# Out:
# (1726, 2)
# (1726,)

# %%
#RNN- 데이터 형변환 [samples, timesteps, features]
n_features = 1
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], n_features))
# x_valid = x_valid.reshape((x_valid.shape[0], x_valid.shape[1], n_features))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], n_features))

print(x_train.shape)  #shape=(2,1) 934개 
print(y_train.shape)  #정답
# Out:
# (1726, 2, 1)
# (1726,)

# %%
#모델 정의
#모델 성능(오류율이 5%미만이면 break, 아니면 10번 시도 후에 break)
i = 0
while True and i < 10:
    model = Sequential()
    model.add(LSTM(64, activation='relu', return_sequences=True, input_shape=(n_step, n_features)))  #input_shape=(2,1)
    model.add(LSTM(128, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    #model training start
    model.fit(x_train, y_train,epochs=350, batch_size=100, verbose=1)

    #학습모델로 test data 예측  
    yhat = model.predict(x_test, verbose=0)
    yhat = minmax_scaler.inverse_transform(yhat)  #원래값으로 변경
    #Mean absolute percentage error - https://en.wikipedia.org/wiki/Mean_absolute_percentage_error
    result = np.mean(abs(test_data[n_step:] - yhat)/test_data[n_step:]) #test_data[n_step:]=test데이터[0],[1]의 y_train값
    if result*100 < 5:
      break
    else:
      del model
      i+=1
# Out:
# Epoch 1/350
# 18/18 [==============================] - 4s 14ms/step - loss: 0.3901
# Epoch 2/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.2699
# Epoch 3/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0895
# Epoch 4/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0193
# Epoch 5/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0117
# Epoch 6/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0106
# Epoch 7/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0097
# Epoch 8/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0088
# Epoch 9/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0083
# Epoch 10/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0077
# Epoch 11/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0074
# Epoch 12/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0073
# Epoch 13/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0072
# Epoch 14/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0074
# Epoch 15/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070
# Epoch 16/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0068
# Epoch 17/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0068
# Epoch 18/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0067
# Epoch 19/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0070
# Epoch 20/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0059
# Epoch 21/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0054
# Epoch 22/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0055
# Epoch 23/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0049
# Epoch 24/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0050
# Epoch 25/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0045
# Epoch 26/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0042
# Epoch 27/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0039
# Epoch 28/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0036
# Epoch 29/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 30/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0034
# Epoch 31/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 32/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 33/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0043
# Epoch 34/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 35/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 36/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 37/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 38/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 39/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 40/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 41/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0030
# Epoch 42/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 43/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 44/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 45/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 46/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 47/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 48/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 49/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 50/350
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0034
# Epoch 51/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0032
# Epoch 52/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 53/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 54/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0030
# Epoch 55/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 56/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 57/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 58/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 59/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 60/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 61/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 62/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 63/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 64/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0028
# Epoch 65/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0025
# Epoch 66/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 67/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 68/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 69/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 70/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 71/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 72/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 73/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 74/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 75/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 76/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0030
# Epoch 77/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 78/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0031
# Epoch 79/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0029
# Epoch 80/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 81/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 82/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 83/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0031
# Epoch 84/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 85/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 86/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 87/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0031
# Epoch 88/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 89/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 90/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 91/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0030
# Epoch 92/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 93/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 94/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 95/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 96/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 97/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 98/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 99/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 100/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 101/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 102/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 103/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 104/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 105/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 106/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0028
# Epoch 107/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 108/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 109/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 110/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 111/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 112/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 113/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 114/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 115/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 116/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 117/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 118/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 119/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 120/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0024
# Epoch 121/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 122/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 123/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 124/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 125/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 126/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 127/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 128/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 129/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 130/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 131/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 132/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 133/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 134/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 135/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 136/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 137/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 138/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 139/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 140/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 141/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 142/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 143/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 144/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 145/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 146/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 147/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 148/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 149/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 150/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 151/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0021
# Epoch 152/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 153/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 154/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 155/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 156/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 157/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 158/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 159/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0020
# Epoch 160/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 161/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 162/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0023
# Epoch 163/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 164/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 165/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0024
# Epoch 166/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 167/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 168/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 169/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 170/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 171/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 172/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 173/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0024
# Epoch 174/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 175/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 176/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 177/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 178/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 179/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 180/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 181/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 182/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 183/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 184/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 185/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 186/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 187/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 188/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 189/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 190/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 191/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 192/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 193/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 194/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0031
# Epoch 195/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 196/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0028
# Epoch 197/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 198/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 199/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 200/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 201/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 202/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 203/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 204/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 205/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 206/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 207/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 208/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 209/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 210/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 211/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 212/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 213/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 214/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 215/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 216/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 217/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 218/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 219/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 220/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 221/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 222/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 223/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 224/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0026
# Epoch 225/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 226/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 227/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 228/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 229/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 230/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0027
# Epoch 231/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 232/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 233/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 234/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0022
# Epoch 235/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 236/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 237/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 238/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 239/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 240/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 241/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 242/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 243/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 244/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 245/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 246/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 247/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 248/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 249/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 250/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 251/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 252/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 253/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 254/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 255/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 256/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 257/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 258/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 259/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 260/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 261/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 262/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 263/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0023
# Epoch 264/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 265/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 266/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 267/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 268/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 269/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 270/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 271/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 272/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 273/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 274/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 275/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 276/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 277/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 278/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 279/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 280/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 281/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 282/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 283/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 284/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 285/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 286/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 287/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 288/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 289/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 290/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 291/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 292/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 293/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 294/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0019
# Epoch 295/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 296/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 297/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 298/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 299/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 300/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 301/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 302/350
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0021
# Epoch 303/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0020
# Epoch 304/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 305/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 306/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 307/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 308/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 309/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 310/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 311/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 312/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 313/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 314/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 315/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 316/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 317/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0017
# Epoch 318/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 319/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 320/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 321/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 322/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0017
# Epoch 323/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 324/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 325/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 326/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 327/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 328/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0018
# Epoch 329/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 330/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 331/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 332/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 333/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 334/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 335/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 336/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 337/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 338/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 339/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 340/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0018
# Epoch 341/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 342/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 343/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 344/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 345/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 346/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 347/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 348/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 349/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 350/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020

# %%
f=open('output.csv','w')
for i in range(len(x_test)):
  f.write(str(test_data[i+2][0])+','+str(yhat[i][0])+'\n')
f.close()

# %%
# x_test=[1,2,3,4,5]
# yhat=[2,3,4,5,6]
# f=open('output.csv','w')
# for j in range(10):
#   for i in range(len(x_test)):
#     f.write(str(x_test[i])+','+str(yhat[i])+'\n')
# f.close()

# %%
result = np.mean(abs(test_data[n_step:] - yhat)/test_data[n_step:])*100  #test_data[n_step:]=test데이터[0],[1]의 y_train값
print(result)
# Out:
# 3.658009681929861

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 5))
ax1 = fig.add_subplot(1, 1, 1)
ax1.plot(test_data[n_step:], 'b', label='Original')
ax1.plot(yhat, 'r', label='Prediction')
ax1.legend(loc="lower right")

# %% [markdown]
# # **전력+온도**

# %%
#계절별 데이터 가져오기  
def find_season2(W_season):
  is_season_data = data['season'] == W_season
  season_data2 = data[is_season_data]
  columns = ['P.D', 'Temp']
  season_data2 = season_data2[columns]
  heat_data2=pd.DataFrame(season_data2)
  heat_data2['P.D']=pd.to_numeric(heat_data2['P.D'])
  heat_data2['Temp']=pd.to_numeric(heat_data2['Temp'])
  heat_data2 = np.array(heat_data2)
  return heat_data2

# %%
heat_data2=find_season2('winter')

#전체 날짜 수(1시간단위=>24)
number_of_whole_day = int(len(heat_data2)/24)
print(f"Number of Whole day: {number_of_whole_day}")

# #하루를 예측하는 것이므로 하루를 제외한 나머지는 train+vald으로 지정
# number_of_trainval_day=number_of_whole_day-1
# print(f"Number of train and validation day: {number_of_trainval_day}")

#train+val에서 80%를 훈련셋으로 지정  
number_of_train_day = int(number_of_whole_day * 0.8) 
print(f"Number of train day: {number_of_train_day}")
# Out:
# Number of Whole day: 90
# Number of train day: 72

# %%
#train_data중에서 
train_data2=heat_data2[:number_of_train_day*24]
print(f"Number of train data: {train_data2.shape}")

# valid_data2=heat_data2[number_of_train_day*24:-24]
# print(f"Number of validation data: {valid_data2.shape}")

test_data2=heat_data2[-24:]
print(f"Number of test data: {test_data2.shape}")
# Out:
# Number of train data: (1728, 2)
# Number of test data: (24, 2)

# %%
minmax_scaler = MinMaxScaler(feature_range=(0, 1))

#데이터 스케일링(0,1 사이값으로 변환)
min_max_normalized_train_data2=minmax_scaler.fit_transform(train_data2)

#fit은 사용하면 안됨.train data에서 fit했던 기준들을 이용해야하기 때문
# min_max_normalized_valid_data2= minmax_scaler.transform(valid_data2)
min_max_normalized_test_data2= minmax_scaler.transform(test_data2)

# %%
#numpy를 pandas로 변환
min_max_normalized_train_data2 = pd.DataFrame(min_max_normalized_train_data2)
# min_max_normalized_valid_data2 = pd.DataFrame(min_max_normalized_valid_data2)
min_max_normalized_test_data2 = pd.DataFrame(min_max_normalized_test_data2)

# %%
#학습데이터, 정답데이터 배열로 return  
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    start = sequence.index.start
    for i in range(start, len(sequence)+start):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > start + len(sequence)-1:
            break
        # gather input and output parts of the pattern
        if start > 90:
            a = i - start
            b = end_ix - start
        else:
            a = i
            b = end_ix
        # 전력+온도 데이터(다중요인)이므로 values값을 넣어야함.
        seq_x, seq_y = sequence[a:b].values, sequence[0][b]  
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
n_step = 2

x_train2, y_train2 = split_sequence(min_max_normalized_train_data2, n_step)
# x_valid2, y_valid2 = split_sequence(min_max_normalized_valid_data2, n_step)
x_test2, y_test2 = split_sequence(min_max_normalized_test_data2, n_step)

print(x_train2.shape)
print(y_train2.shape)
# Out:
# (1726, 2, 2)
# (1726,)

# %%
#RNN- 데이터 형변환 [samples, timesteps, features]
n_features = 2
x_train2 = x_train2.reshape((x_train2.shape[0], x_train2.shape[1], n_features))
# x_valid2 = x_valid2.reshape((x_valid2.shape[0], x_valid2.shape[1], n_features))
x_test2 = x_test2.reshape((x_test2.shape[0], x_test2.shape[1], n_features))

print(x_train2.shape)  
print(y_train2.shape)  #정답
print(x_test2.shape)
# Out:
# (1726, 2, 2)
# (1726,)
# (22, 2, 2)

# %%
#예측값과 비교할 x_test의 전력 
test_data2_new=min_max_normalized_test_data2[0][2:]
test_data2_new=pd.DataFrame(test_data2_new)
new=[]

for i in range(2,len(min_max_normalized_test_data2)):
    new_=[]
    new_.append(test_data2_new[0][i])
    new.append(new_)
new[:5]
# Out:
# [[0.45044878205365635],
#  [0.4501524747830167],
#  [0.45073274318801926],
#  [0.49061076336160603],
#  [0.5634282751213008]]

# %%
#모델 정의
#모델 성능(오류율이 5%미만이면 break, 아니면 10번 시도 후에 break)
i = 0
while True and i < 10:
    model = Sequential()
    model.add(LSTM(64, activation='relu', return_sequences=True, input_shape=(n_step, n_features)))  #input_shape=(2,1)
    model.add(LSTM(128, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    #model training start
    model.fit(x_train2, y_train2,epochs=350, batch_size=100, verbose=1)

    #학습모델로 test data 예측  
    yhat = model.predict(x_test2, verbose=0)
    # yhat = minmax_scaler.inverse_transform(yhat)  #원래값으로 변경
    #Mean absolute percentage error - https://en.wikipedia.org/wiki/Mean_absolute_percentage_error
    result = np.mean(abs(new - yhat)/new) 
    if result*100 < 5:
      break
    else:
      del model
      i+=1
# Out:
# Epoch 1/350
# 18/18 [==============================] - 5s 14ms/step - loss: 0.3796
# Epoch 2/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.2152
# Epoch 3/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0326
# Epoch 4/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0193
# Epoch 5/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0160
# Epoch 6/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0136
# Epoch 7/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0109
# Epoch 8/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0096
# Epoch 9/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0080
# Epoch 10/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0076
# Epoch 11/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0073
# Epoch 12/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0079
# Epoch 13/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0079
# Epoch 14/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0077
# Epoch 15/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0069
# Epoch 16/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0068
# Epoch 17/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0074
# Epoch 18/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0070
# Epoch 19/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0070
# Epoch 20/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0076
# Epoch 21/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0068
# Epoch 22/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0070
# Epoch 23/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0076
# Epoch 24/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0065
# Epoch 25/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0064
# Epoch 26/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0064
# Epoch 27/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0070
# Epoch 28/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0077
# Epoch 29/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0067
# Epoch 30/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0062
# Epoch 31/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0067
# Epoch 32/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0068
# Epoch 33/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0062
# Epoch 34/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0057
# Epoch 35/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0056
# Epoch 36/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0061
# Epoch 37/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0052
# Epoch 38/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0051
# Epoch 39/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0049
# Epoch 40/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0052
# Epoch 41/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0044
# Epoch 42/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0039
# Epoch 43/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0041
# Epoch 44/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0037
# Epoch 45/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 46/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 47/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 48/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0035
# Epoch 49/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 50/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 51/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0032
# Epoch 52/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0033
# Epoch 53/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0034
# Epoch 54/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 55/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 56/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0028
# Epoch 57/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 58/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 59/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 60/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0029
# Epoch 61/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 62/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 63/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0035
# Epoch 64/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 65/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0030
# Epoch 66/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 67/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 68/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 69/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 70/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 71/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 72/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0031
# Epoch 73/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 74/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 75/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 76/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0029
# Epoch 77/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0024
# Epoch 78/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 79/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 80/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 81/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 82/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 83/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 84/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 85/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 86/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 87/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0024
# Epoch 88/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 89/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 90/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 91/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 92/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 93/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 94/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 95/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 96/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 97/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 98/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 99/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 100/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 101/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 102/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 103/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 104/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 105/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 106/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 107/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 108/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 109/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 110/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 111/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 112/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 113/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 114/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 115/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 116/350
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 117/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 118/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 119/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 120/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 121/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 122/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 123/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 124/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 125/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 126/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 127/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 128/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 129/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 130/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 131/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 132/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 133/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 134/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 135/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 136/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 137/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 138/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 139/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 140/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 141/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 142/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 143/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 144/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 145/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 146/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 147/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 148/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 149/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 150/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 151/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 152/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 153/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 154/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 155/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 156/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 157/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 158/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 159/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 160/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 161/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 162/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 163/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 164/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 165/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 166/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 167/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 168/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 169/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 170/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 171/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 172/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 173/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 174/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 175/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 176/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 177/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 178/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 179/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 180/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 181/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0023
# Epoch 182/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 183/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 184/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 185/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 186/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 187/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 188/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 189/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 190/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 191/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 192/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 193/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0028
# Epoch 194/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 195/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 196/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 197/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 198/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 199/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 200/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 201/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 202/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 203/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 204/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 205/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 206/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 207/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 208/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 209/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 210/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 211/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 212/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 213/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 214/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 215/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 216/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 217/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 218/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 219/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 220/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 221/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0021
# Epoch 222/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 223/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 224/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 225/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 226/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 227/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 228/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 229/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 230/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0028
# Epoch 231/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 232/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 233/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 234/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 235/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 236/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 237/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 238/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 239/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 240/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 241/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 242/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 243/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 244/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 245/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 246/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 247/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 248/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 249/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 250/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 251/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 252/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 253/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 254/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 255/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 256/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 257/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 258/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 259/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 260/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 261/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 262/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 263/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 264/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0018
# Epoch 265/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 266/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 267/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 268/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0023
# Epoch 269/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 270/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0028
# Epoch 271/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 272/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 273/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 274/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 275/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 276/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0024
# Epoch 277/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 278/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 279/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 280/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 281/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 282/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 283/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 284/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 285/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 286/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 287/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 288/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 289/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 290/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 291/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 292/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 293/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 294/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 295/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 296/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 297/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 298/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0020
# Epoch 299/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 300/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 301/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 302/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 303/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 304/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 305/350
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0022
# Epoch 306/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 307/350
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0021
# Epoch 308/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 309/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 310/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 311/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 312/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 313/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 314/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0017
# Epoch 315/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 316/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 317/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 318/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 319/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 320/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 321/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 322/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 323/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 324/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 325/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 326/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 327/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 328/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 329/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 330/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 331/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 332/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 333/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 334/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 335/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 336/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 337/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 338/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 339/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 340/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 341/350
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 342/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 343/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 344/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 345/350
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0018
# Epoch 346/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 347/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 348/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 349/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 350/350
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0020

# %%
f=open('output.csv','w')
for i in range(len(x_test2)):
  f.write(str(new[i][0])+','+str(yhat[i][0])+'\n')
f.close()

# %%
for i in range(0,len(x_test2)):
  a=abs(new- yhat)/new
  np.nan_to_num(a,copy=False)  #inf를 숫자형으로 
result=np.mean(a)*100
result
# Out:
# 4.558608055296378

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 5))
ax1 = fig.add_subplot(1, 1, 1)
ax1.plot(new, 'b', label='Original')
ax1.plot(yhat, 'r', label='Prediction')
ax1.legend(loc="lower right")
